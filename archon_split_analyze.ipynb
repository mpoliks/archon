# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Building wheels for collected packages: progressbar
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=9b62905c6352da510085d85efb0d7895c57dcff76c6a7c9a1f65b705c87ed07d
#   Stored in directory: /root/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# Successfully built progressbar
# Installing collected packages: progressbar
# Successfully installed progressbar-2.5

# %%
from pydub import AudioSegment
import math

class SplitWav():
    def __init__(self, filename, destination):
        self.dest = destination
        self.filename = filename
        
        self.audio = AudioSegment.from_wav(self.filename)
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_sec, to_sec, split_filename):
        t1 = from_sec * 1000
        t2 = to_sec * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(self.dest + '/' + split_filename, format="wav")
        
    def multiple_split(self, filebase, sec_per_split):
        total_sec = int(self.get_duration())
        for i in range(0, total_sec, sec_per_split):
            filebase = filebase.rsplit( ".", 1)[0]
            split_fn = str(filebase) + "_" + str(i) + ".wav"
            self.single_split(i, i + sec_per_split, split_fn)
            if i == total_sec - sec_per_split:
                print('All splited successfully')

# %%
import os, os.path

counter = 0
destination_db = "/content/drive/My Drive/justatest/"
directory_db = "/content/drive/My Drive/CompleteFabricMixes_22050/"
datasize = len([name for name in os.listdir(directory_db) if os.path.isfile(os.path.join(directory_db, name))])

for filename in os.scandir(directory_db):
  if (filename.path.endswith(".wav")):  
    split_wav = SplitWav(filename, destination_db)
    split_wav.multiple_split(filename.name, sec_per_split = 3)
    counter += 1
    print("completed " + str(counter) + " of " + str(datasize))
# Out:
# All splited successfully
# completed 1 of 687
# All splited successfully
# completed 2 of 687
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bec68d47a91a> in <module>()
#       8 for filename in os.scandir(directory_db):
#       9   if (filename.path.endswith(".wav")):
# ---> 10     split_wav = SplitWav(filename, destination_db)
#      11     split_wav.multiple_split(filename.name, sec_per_split = 3)
#      12     counter += 1
#
# <ipython-input-9-c572f8e01c21> in __init__(self, filename, destination)
#       7         self.filename = filename
#       8
# ----> 9         self.audio = AudioSegment.from_wav(self.filename)
#      10
#      11     def get_duration(self):
#
# /usr/local/lib/python3.7/dist-packages/pydub/audio_segment.py in from_wav(cls, file, parameters)
#     806     @classmethod
#     807     def from_wav(cls, file, parameters=None):
# --> 808         return cls.from_file(file, 'wav', parameters=parameters)
#     809
#     810     @classmethod
#
# /usr/local/lib/python3.7/dist-packages/pydub/audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     778         fix_wav_headers(p_out)
#     779         p_out = bytes(p_out)
# --> 780         obj = cls(p_out)
#     781
#     782         if close_file:
#
# /usr/local/lib/python3.7/dist-packages/pydub/audio_segment.py in __init__(self, data, *args, **kwargs)
#     250                 byte_buffer.write(padding[b2 > b'\x7f'[0]])
#     251                 old_bytes = struct.pack(pack_fmt, b0, b1, b2)
# --> 252                 byte_buffer.write(old_bytes)
#     253
#     254             self._data = byte_buffer.getvalue()
#
# KeyboardInterrupt:

# %% [markdown]
# TODO:

# %%
directory = "/content/drive/My Drive/TestJSON/TestInput" #@param {type:"string"}
hop_length = "1024" #@param {type:"string"}
sr = "44100" #@param {type:"string"}
output_filename = "AUDIOS_output.json" #@param {type:"string"}

hop_length = int(hop_length)
sr = int(sr)

# %%
import numpy as np
import json as json
from IPython.display import HTML, display
import time

# %%
# !pip install librosa==0.8.0
import librosa
print(librosa.__version__)
# Out:
# 0.8.0

# %%
hop = hop_length
counter = 0
data=[]
datasize = len([name for name in os.listdir(directory) if os.path.isfile(os.path.join(directory, name))])

for filename in os.scandir(directory):
  if (filename.path.endswith(".wav")):
    y, sr = librosa.load(filename, sr=sr)
    cent = np.ndarray.flatten(
        librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=hop))
    flat = np.ndarray.flatten(
        librosa.feature.spectral_flatness(y=y, hop_length=hop))
    rolloff = np.ndarray.flatten(
        librosa.feature.spectral_rolloff(y=y, sr=sr, hop_length=hop))
    rms = np.ndarray.flatten(
        librosa.feature.rms(y=y, hop_length=hop))
    f0 = np.ndarray.flatten(
        librosa.yin(y,80,10000, hop_length=hop))
    id = filename

    for x in range(cent.size):
      data.append({str(x * hop_length): {
        "cent": str(cent[x]),
        "flat": str(flat[x]),
        "rolloff": str(rolloff[x]),
        "rms": str(rms[x]),
        "f0": str(f0[x]),
        "id": str(filename.path),
        "sample": str(x * hop_length)}
      })
    counter += 1
    print("completed " + str(counter) + " of " + str(datasize))

savefile = filename.path + ".json"
with open(savefile, 'a') as outfile:
  json.dump(data, outfile, indent=2)

print(savefile)
# Out:
# completed 1 of 1
# /content/drive/My Drive/TestJSON/TestInput/Roberto_output.wav.json

# %%
# !ls -lah
# Out:
# total 1.1G
# -rw------- 1 root root 1.1G Mar 16 15:49 AUDIOS_output.json
# -rw------- 1 root root 4.1M Mar 15 21:01 Roberto_output.wav
